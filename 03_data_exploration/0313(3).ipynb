# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
font_dir = ['C:/python/fonts']
for font in mpl.font_manager.findSystemFonts(fontpaths=font_dir):
    print(mpl.font_manager.FontProperties(fname=font).get_name())
    mpl.font_manager.fontManager.addfont(font)
# Out:
# NanumBarunGothic YetHangul
# Noto Sans KR
# NanumMyeongjo
# NanumSquare
# NanumGothic
# NanumBarunGothic
# Nanum Pen Script
# D2Coding ligature
# NanumSquareOTF
# NanumMyeongjo Eco
# Nanum Brush Script OTF
# NanumMyeongjo YetHangul
# NanumBarunGothicOTF
# NanumSquare
# NanumGothic Eco
# NanumMyeongjoOTF
# NanumSquare_ac
# NanumSquareRound
# NanumSquareRound
# NanumGothicOTF Eco
# Noto Sans KR
# NanumMyeongjoOTF
# NanumBarunGothic
# NanumBarunGothic
# NanumBarunGothicOTF
# NanumGothic
# NanumSquareOTF
# NanumSquareRoundOTF
# NanumSquare Neo OTF Bold
# NanumGothicOTF Eco
# NanumBarunpen
# NanumSquare Neo ExtraBold
# NanumSquareOTF_ac
# NanumGothic
# NanumSquare_ac
# NanumSquareRoundOTF
# D2Coding ligature
# Noto Sans KR
# NanumMyeongjo
# NanumSquare Neo OTF Light
# NanumGothicOTF
# NanumSquare Neo Light
# NanumSquare Neo OTF ExtraBold
# NanumMyeongjo
# NanumGothicOTF Eco
# NanumBarunGothicOTF
# NanumSquareOTF
# NanumMyeongjo
# Nanum Pen Script OTF
# NanumSquare Neo OTF Heavy
# NanumSquareOTF_ac
# NanumMyeongjo
# NanumMyeongjoOTF
# NanumSquare Neo Heavy
# NanumSquareRound
# NanumMyeongjo Eco
# NanumSquareRoundOTF
# NanumMyeongjoOTF Eco
# NanumSquareOTF_ac
# NanumSquareRoundOTF
# NanumSquare_ac
# NanumBarunpenOTF
# Nanum Brush Script
# NanumSquareOTF_ac
# NanumMyeongjoOTF YetHangul
# NanumGothic Eco
# NanumSquareOTF
# NanumGothicOTF
# NanumMyeongjo Eco
# D2Coding
# Noto Sans KR
# NanumMyeongjoOTF Eco
# NanumGothicOTF
# NanumSquare Neo Bold
# NanumSquare_ac
# NanumBarunGothicOTF
# NanumBarunpen
# NanumSquareRound
# NanumGothic
# NanumBarunGothic
# Noto Sans KR
# NanumSquare
# NanumSquare Neo Regular
# NanumSquare
# NanumSquare Neo OTF Regular
# NanumGothic Eco
# NanumMyeongjoOTF Eco
# NanumBarunpenOTF
# D2Coding ligature
# NanumBarunGothicOTF YetHangul
# NanumMyeongjo
# NanumGothicOTF
# Noto Sans KR

# %%
mpl.rcParams['font.family'] = 'Noto Sans KR'
print(mpl.rcParams['font.family'])
# Out:
# ['Noto Sans KR']

# %%
# 바 차트 
# x 데이터가 카테고리 값인 경우

y = [2, 3, 1]
x = ['가', '나', '다']
plt.title("Bar Chart")
plt.bar(x, y)
plt.xlabel("가나다")
plt.ylabel("빈도 수")
plt.show()

# %%
# 각 bar 마다 색상을 적용

y = [2, 3, 1]
x = ['가', '나', '다']
colors = ['red', 'green', 'blue']

plt.title("Bar Chart")
plt.bar(x, y, color=colors)
plt.xlabel("가나다")
plt.ylabel("빈도 수")
plt.show()

# %%
# xerr 인수나 yerr 인수를 지정: 에러 바(error bar) 추가 가능
# alpha는 투명도를 지정

np.random.seed(0)

people = ['몽룡', '춘향', '방자', '향단']
performance = 3+10*np.random.rand(len(people))
error=np.random.rand(len(people))

plt.title("Barh Chart")
plt.barh(people, performance, xerr=error, alpha=0.4)
plt.xlabel('x 라벨')
plt.show()

# %%
# 연습 문제

import numpy as np
import seaborn as sns
titanic = sns.load_dataset("titanic")

number = [len(titanic.loc[titanic.survived == 0]), len(titanic.loc[titanic.survived == 1])]
people = ["사망자", "생존자"]
colors = ['red', 'green']

plt.title("타이타닉호 생존 여부")
plt.barh(people, number, color=colors)
plt.xlabel("인원 수")
plt.show()

# %%
# 또다른 풀이

bar_chart = titanic['alive'].value_counts()
bar_chart.rename({'no': '사망자', 'yes': '생존자'}, inplace=True)
bar_chart
# Out:
# 사망자    549
# 생존자    342
# Name: alive, dtype: int64

# %%
alive = bar_chart.index
value = bar_chart.values
bar_colors = ['red', 'green']

plt.title("타이타닉호 생존 여부")
plt.barh(alive, value, color=bar_colors)
plt.xlabel("인원 수")
plt.show()

# %%
# 파이 차트
# 카테고리 별 값의 상대적인 비교

labels = ['월세', '전세', '자가', '기타']
sizes = [15, 30, 45, 10]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
explode = (0, 0, 0.1, 0)
plt.title("Pie Chart")
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')    # 원의 형태를 유지
plt.show()

# 1.1: 소수점 아래 첫째 자리까지 표시
# %%: % 붙임

# %%
# 연습문제

import pandas as pd

titanic = sns.load_dataset("titanic")
bins = [0, 20, 30, 50, 70, 100]
labels = ['미성년자', '청년', '장년', '중년', '노년']

# Nan을 제외한 age column
titanic_age = titanic[titanic["age"].notnull()]["age"]

size = pd.cut(titanic_age, bins=bins, labels=labels).value_counts(normalize=True)

explode = (0.1, 0, 0, 0, 0)
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral', 'orange']

plt.pie(sizes, explode=explode, labels=size.index, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')
plt.show()

# %%
# 히스토그램

np.random.seed(0)
x = np.random.randn(1000)
plt.title("Histogram")
arrays, bins, patches = plt.hist(x, bins=10)
plt.show()

# %%
arrays
# Out:
# array([  9.,  20.,  70., 146., 217., 239., 160.,  86.,  38.,  15.])

# %%
bins
# Out:
# array([-3.04614305, -2.46559324, -1.88504342, -1.3044936 , -0.72394379,
#        -0.14339397,  0.43715585,  1.01770566,  1.59825548,  2.1788053 ,
#         2.75935511])

# %%
# 스캐터 플롯

# 2차원 데이터, 즉 두 개의 실수 데이터 집합의 상관관계
# 스캐터 플롯의 점 하나의 위치는 데이터 하나의 x, y 값

np.random.seed(0)
X = np.random.normal(0, 1, 100)
Y = np.random.normal(0, 1, 100)
plt.title("Scatter Plot")
plt.scatter(X, Y)
plt.show()

# %%
# 스캐터 플롯

# 데이터가 2차원이 아니라 3차원 혹은 4차원인 경우
# 버블 차트(bubble chart): 점 하나의 크기 혹은 색깔을 이용하여 다른 데이터 값을 나타냄
# 크기는 s 인수로 색깔은 c 인수로 지정

N = 30
np.random.seed(0)
x = np.random.rand(N)
y1 = np.random.rand(N)
y2 = np.random.rand(N)
y3 = np.pi * (15 * np.random.rand(N)) ** 2
plt.title("Bubble Chart")
plt.scatter(x, y1, c = y2, s = y3)
plt.show()

# %%
# imshow
# 화상(image) 데이터처럼 행과 열을 가진 행렬 형태의 2차원 데이터
# 2차원 자료의 크기를 색깔로 표시

from sklearn.datasets import load_digits
digits = load_digits()
X = digits.images[0]
X
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
plt.title("mnist digits; 0")
plt.imshow(X, interpolation='nearest', cmap=plt.cm.bone_r)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.subplots_adjust(left=0.35, right=0.65, bottom=0.35, top=0.65)
plt.show()

# %%
# 칼라맵(color map): 데이터 수치를 색으로 바꾸는 함수
# 칼라맵은 cmap 인수로 지정
# 사용할 수 있는 칼라맵은 plt.cm의 속성으로 포함되어 있음

dir(plt.cm)[:10]    # 일부 칼라맵 표시
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r']

# %%
# cmap 키워드 인수를 사용하여 다양한 색상으로 변경된 결과를 출력

fig,axes = plt.subplots(1, 4, figsize = (12, 3),
                        subplot_kw = {'xticks' : [], 'yticks' : []})
axes[0].set_title("plt.cm.Blues")
axes[0].imshow(X, interpolation = 'nearest', cmap = plt.cm.Blues)

axes[1].set_title("plt.cm.Blues_r")
axes[1].imshow(X, interpolation = 'nearest', cmap = plt.cm.Blues_r)

axes[2].set_title("plt.BrBG")
axes[2].imshow(X, interpolation = 'nearest', cmap = 'BrBG')

axes[3].set_title("plt.BrBG_r")
axes[3].imshow(X, interpolation = 'nearest', cmap = 'BrBG_r')

plt.show()

# %%
# imshow 명령은 자료의 시각화를 돕기위해 다양한 2차원 인터폴레이션을 지원

methods = {
    None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16', 'spline36',
    'hanning', 'hamming', 'hermite', 'kaiser', 'quadric', 'catrom', 'gaussian',
    'bessel', 'mitchell', 'sinc', 'lanczos'
}
fig, axes = plt.subplots(3, 6, figsize = (12, 6),
                         subplot_kw = {'xticks' : [], 'yticks' : []})
for ax, interp_method in zip(axes.flat, methods):
    ax.imshow(X, cmap = plt.cm.bone_r, interpolation = interp_method)
    ax.set_title(interp_method)
    
plt.show()

# %%
# 컨투어 플롯

# 입력 변수가 x, y 두 개이고 출력 변수가 z 하나인 경우에는 3차원 자료가 됨
# 3차원 자료를 시각화: 등고선(contour)을 사용
# contour는 등고선만 표시하고 contourf는 색깔로 표시
# 입력 변수 x, y는 그대로 사용할 수 없고 meshgrid 명령으로 그리드 포인트 행렬을 만들어야 함

def f(x, y):
    return (1 - x / 2 + x ** 5 + y ** 3) * np.exp(-x ** 2 - y ** 2)

n = 256
x = np.linspace(-3, 3, n)
y = np.linspace(-3, 3, n)
XX, YY = np.meshgrid(x, y)
ZZ = f(XX, YY)

plt.title("Contour plots")
plt.contourf(XX, YY, ZZ, alpha = .75, cmap = 'jet')
plt.contour(XX, YY, ZZ, colors = 'black')
plt.show()

# %%
# 3D 서피스 플롯
# Axes3D라는 3차원 전용 axes를 생성하여 입체적으로 표시
# plot_wireframe(), plot_surface() 명령을 사용

from mpl_toolkits.mplot3d import Axes3D
X = np.arange(-4, 4, 0.25)
Y = np.arange(-4, 4, 0.25)
XX, YY = np.meshgrid(X, Y)
RR = np.sqrt(XX ** 2 + YY ** 2)
ZZ = np.sin(RR)

fig = plt.figure()
ax = Axes3D(fig)
ax.set_title('3D Surface Plot')
ax.plot_surface(XX, YY, ZZ, rstride = 1, cstride = 1, cmap = 'hot')
plt.show()
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_6348\533660281.py:13: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
