# %%
import pandas as pd

# %%
a = pd.read_excel('C:/python/datas/emergency.xlsx')
a
# Out:
#           번호    안전비상벨관리번호 설치목적 설치장소유형          설치위치  \
# 0          1  C-JH02-0051  방범용    가로변           가로변
# 1          2  C-JH02-0052  방범용    가로변           가로변
# 2          3  C-JH02-0053  방범용    가로변           가로변
# 3          4  C-MK01-0001  방범용    가로변           가로변
# 4          5  C-MK01-0002  방범용    가로변           가로변
# ...      ...          ...  ...    ...           ...
# 22176  22177     생활방범-440  방범용    가로변    중곡4동 76-56
# 22177  22178     그린파킹-051  방범용    가로변   자양1동 223-20
# 22178  22179     그린파킹-052  방범용    가로변   중곡2동 128-14
# 22179  22180     그린파킹-053  방범용    가로변  중곡3동 191-107
# 22180  22181     시설방범-001  방범용    가로변     군자동 478-5
#
#                          소재지도로명주소 소재지지번주소    WGS84위도     WGS84경도 연계방식 경찰연계유무  \
# 0            서울특별시 중랑구 중랑역로3가길 31     NaN  37.596303  127.074803  단방향      N
# 1           서울특별시 중랑구 봉화산로3길 53-8     NaN  37.604046  127.075133  단방향      N
# 2            서울특별시 중랑구 중랑천로14길 24     NaN  37.594137  127.073886  단방향      N
# 3             서울특별시 중랑구 동일로152길 5     NaN  37.608485  127.078624  단방향      N
# 4            서울특별시 중랑구 동일로160길 12     NaN  37.610617  127.078514  단방향      N
# ...                           ...     ...        ...         ...  ...    ...
# 22176  서울특별시 광진구 긴고랑로38길 14 (중곡동)     NaN  37.558510  127.090360  양방향      N
# 22177         서울특별시 광진구아차산로42길 16     NaN  37.537010  127.078940  양방향      N
# 22178          서울특별시 광진구용마산로5길 40     NaN  37.557600  127.085590  양방향      N
# 22179          서울특별시 광진구동일로74길 15     NaN  37.567090  127.078920  양방향      N
# 22180           서울특별시 광진구천호대로 548     NaN  37.567090  127.078920  양방향      N
#
#       경비업체연계유무 관리사무소연계유무 부가기능  안전비상벨설치연도      최종점검일자 최종점검결과구분       관리기관명  \
# 0            N         N  NaN       2017  2020-03-02        Y  서울특별시 중랑구청
# 1            N         N  NaN       2017  2020-03-02        Y  서울특별시 중랑구청
# 2            N         N  NaN       2017  2020-03-02        Y  서울특별시 중랑구청
# 3            N         N  NaN       2005  2020-03-02        Y  서울특별시 중랑구청
# 4            N         N  NaN       2005  2020-03-02        Y  서울특별시 중랑구청
# ...        ...       ...  ...        ...         ...      ...         ...
# 22176        N         N  NaN       2018  2022-12-31        Y        광진구청
# 22177        N         N  NaN       2014  2022-12-31        Y        광진구청
# 22178        N         N  NaN       2014  2022-12-31        Y        광진구청
# 22179        N         N  NaN       2014  2022-12-31        Y        광진구청
# 22180        N         N  NaN       2017  2022-12-31        Y        광진구청
#
#            관리기관전화번호     데이터기준일자
# 0      02-2094-0284  2020-03-17
# 1      02-2094-0284  2020-03-17
# 2      02-2094-0284  2020-03-17
# 3      02-2094-0284  2020-03-17
# 4      02-2094-0284  2020-03-17
# ...             ...         ...
# 22176   02-450-7678  2023-03-13
# 22177   02-450-7678  2023-03-13
# 22178   02-450-7678  2023-03-13
# 22179   02-450-7678  2023-03-13
# 22180   02-450-7678  2023-03-13
#
# [22181 rows x 20 columns]

# %%
a.columns
# Out:
# Index(['번호', '안전비상벨관리번호', '설치목적', '설치장소유형', '설치위치', '소재지도로명주소', '소재지지번주소',
#        'WGS84위도', 'WGS84경도', '연계방식', '경찰연계유무', '경비업체연계유무', '관리사무소연계유무', '부가기능',
#        '안전비상벨설치연도', '최종점검일자', '최종점검결과구분', '관리기관명', '관리기관전화번호', '데이터기준일자'],
#       dtype='object')

# %%
# '아네'라는 컬럼을 새로 추가, 
# 데이터는 '소재지도로명주소'를 string method를 통해 공백을 기준으로 슬라이싱
# 슬라이싱된 값으니 1번 인덱스 자리(왼쪽에서 2번째) 값을 반환

a['아네'] = a['소재지도로명주소'].str.split().str[1]

# %%
# '아네'에서 NaN 값인 자리에 소재지 지번 주소 삽입

a.loc[a['아네'].isna() & a['소재지지번주소'].notnull(), '아네'] = a['소재지지번주소'].str.split().str[1]

# %%
# '아네' 컬럼 안에 NaN값의 합 계산

a["아네"].isna().sum()
# Out:
# 0

# %%
# 컬럼의 길이 파악

len(a)
# Out:
# 22181

# %%
a.소재지도로명주소 = a.소재지도로명주소.str[5:]

# %%
a
# Out:
#           번호    안전비상벨관리번호 설치목적 설치장소유형          설치위치               소재지도로명주소  \
# 0          1  C-JH02-0051  방범용    가로변           가로변         중랑구 중랑역로3가길 31
# 1          2  C-JH02-0052  방범용    가로변           가로변        중랑구 봉화산로3길 53-8
# 2          3  C-JH02-0053  방범용    가로변           가로변         중랑구 중랑천로14길 24
# 3          4  C-MK01-0001  방범용    가로변           가로변          중랑구 동일로152길 5
# 4          5  C-MK01-0002  방범용    가로변           가로변         중랑구 동일로160길 12
# ...      ...          ...  ...    ...           ...                    ...
# 22176  22177     생활방범-440  방범용    가로변    중곡4동 76-56   광진구 긴고랑로38길 14 (중곡동)
# 22177  22178     그린파킹-051  방범용    가로변   자양1동 223-20          광진구아차산로42길 16
# 22178  22179     그린파킹-052  방범용    가로변   중곡2동 128-14           광진구용마산로5길 40
# 22179  22180     그린파킹-053  방범용    가로변  중곡3동 191-107           광진구동일로74길 15
# 22180  22181     시설방범-001  방범용    가로변     군자동 478-5            광진구천호대로 548
#
#       소재지지번주소    WGS84위도     WGS84경도 연계방식  ... 경비업체연계유무 관리사무소연계유무 부가기능  \
# 0         NaN  37.596303  127.074803  단방향  ...        N         N  NaN
# 1         NaN  37.604046  127.075133  단방향  ...        N         N  NaN
# 2         NaN  37.594137  127.073886  단방향  ...        N         N  NaN
# 3         NaN  37.608485  127.078624  단방향  ...        N         N  NaN
# 4         NaN  37.610617  127.078514  단방향  ...        N         N  NaN
# ...       ...        ...         ...  ...  ...      ...       ...  ...
# 22176     NaN  37.558510  127.090360  양방향  ...        N         N  NaN
# 22177     NaN  37.537010  127.078940  양방향  ...        N         N  NaN
# 22178     NaN  37.557600  127.085590  양방향  ...        N         N  NaN
# 22179     NaN  37.567090  127.078920  양방향  ...        N         N  NaN
# 22180     NaN  37.567090  127.078920  양방향  ...        N         N  NaN
#
#       안전비상벨설치연도      최종점검일자 최종점검결과구분       관리기관명      관리기관전화번호     데이터기준일자  \
# 0          2017  2020-03-02        Y  서울특별시 중랑구청  02-2094-0284  2020-03-17
# 1          2017  2020-03-02        Y  서울특별시 중랑구청  02-2094-0284  2020-03-17
# 2          2017  2020-03-02        Y  서울특별시 중랑구청  02-2094-0284  2020-03-17
# 3          2005  2020-03-02        Y  서울특별시 중랑구청  02-2094-0284  2020-03-17
# 4          2005  2020-03-02        Y  서울특별시 중랑구청  02-2094-0284  2020-03-17
# ...         ...         ...      ...         ...           ...         ...
# 22176      2018  2022-12-31        Y        광진구청   02-450-7678  2023-03-13
# 22177      2014  2022-12-31        Y        광진구청   02-450-7678  2023-03-13
# 22178      2014  2022-12-31        Y        광진구청   02-450-7678  2023-03-13
# 22179      2014  2022-12-31        Y        광진구청   02-450-7678  2023-03-13
# 22180      2017  2022-12-31        Y        광진구청   02-450-7678  2023-03-13
#
#                아네
# 0             중랑구
# 1             중랑구
# 2             중랑구
# 3             중랑구
# 4             중랑구
# ...           ...
# 22176         광진구
# 22177  광진구아차산로42길
# 22178   광진구용마산로5길
# 22179   광진구동일로74길
# 22180     광진구천호대로
#
# [22181 rows x 21 columns]

# %%
pd.set_option('display.max_rows', None)

t = a['아네'].value_counts()[:24]
t
# 필요없는 부분 필터링하기.
# Out:
# 강남구     4229
# 중랑구     1772
# 영등포구    1185
# 동작구     1103
# 구로구     1049
# 성북구     1038
# 관악구      988
# 강서구      964
# 강동구      935
# 송파구      881
# 광진구      860
# 마포구      849
# 동대문구     801
# 금천구      709
# 양천구      674
# 중구       631
# 은평구      611
# 용산구      589
# 서대문구     401
# 종로구       82
# 노원구       37
# 서초구       34
# 강북구       22
# 왕십리로      22
# Name: 아네, dtype: int64

# %%
t1 = t.iloc[0:22]
t1['강북구'] = 22
t1
# Out:
# 강남구     4229
# 중랑구     1772
# 영등포구    1185
# 동작구     1103
# 구로구     1049
# 성북구     1038
# 관악구      988
# 강서구      964
# 강동구      935
# 송파구      881
# 광진구      860
# 마포구      849
# 동대문구     801
# 금천구      709
# 양천구      674
# 중구       631
# 은평구      611
# 용산구      589
# 서대문구     401
# 종로구       82
# 노원구       37
# 서초구       34
# 강북구       22
# Name: 아네, dtype: int64

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
font_dir = ['C:/python/fonts']
for font in mpl.font_manager.findSystemFonts(fontpaths=font_dir):
    mpl.font_manager.fontManager.addfont(font)
    # print(mpl.font_manager.FontProperties(fname=font).get_name())

# %%
mpl.rcParams['font.family'] = 'NanumBarunGothicOTF'
print(mpl.rcParams['font.family'])
# Out:
# ['NanumBarunGothicOTF']

# %%
sns.barplot(y=t1.values, x=t1.index, palette='viridis')
plt.xticks(rotation=45)
plt.title('서울시 자치구별 비상벨 개수')
plt.xlabel('자치구명')
mpl.rcParams['font.size'] = 9
plt.show()
