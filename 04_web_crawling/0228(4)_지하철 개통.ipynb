# %%
# 지하철 개통
import requests
import json
opening = requests.get("https://api.odcloud.kr/api/15044439/v1/uddi:08e41572-cef4-4f08-a508-ef6a54026503?page=1&perPage=41",
                       # page=1&perPage=41 부분애서 뒷 페이지의 숫자를 수정하면 데이터를 불러오는 양이 바뀐다.
                       # 이 데이터는 총 41개의 row가 존재함
                        params = {'serviceKey':'IRtc5EDsiAqy5n+ArSEALCx5ODamXLfZbEXMeJUiK2OnVJH76JJRX/rZzaJdeU7SEgBrdRq2RQhhl2rSvfOH1w=='})
                        # serviceKey는 일반 인증키(Decoding)

print(opening.status_code)  # 200, 연결 확인
opening.headers
# Out:
# 200
# {'Access-Control-Allow-Origin': '*', 'Content-Type': 'application/json; charset=UTF-8', 'Vary': 'Origin', 'Date': 'Tue, 28 Feb 2023 05:03:48 GMT', 'Transfer-Encoding': 'chunked'}

# %%
opening_dict = opening.json() # 지하철 개통 정보를 dict 저장
print(opening_dict)
# Out:
# {'currentCount': 41, 'data': [{'개통일자': '1974-08-15', '구간': '서울↔청량리', '기관': '서울교통공사', '역개수': 9, '연번': 1, '연장(km)': '7.8', '호선': 1}, {'개통일자': '2005-12-21', '구간': '동묘앞', '기관': '서울교통공사', '역개수': 1, '연번': 2, '연장(km)': None, '호선': 1}, {'개통일자': '1980-10-31', '구간': '신설동(2)↔종합운동장', '기관': '서울교통공사', '역개수': 11, '연번': 3, '연장(km)': '14.3', '호선': 2}, {'개통일자': '1982-12-23', '구간': '종합운동장↔교대(2)', '기관': '서울교통공사', '역개수': 5, '연번': 4, '연장(km)': '5.5', '호선': 2}, {'개통일자': '1983-09-16', '구간': '을지입구↔성수', '기관': '서울교통공사', '역개수': 9, '연번': 5, '연장(km)': '7.9', '호선': 2}, {'개통일자': '1983-12-17', '구간': '교대(2)↔서울대입구', '기관': '서울교통공사', '역개수': 5, '연번': 6, '연장(km)': '6.7', '호선': 2}, {'개통일자': '1984-05-22', '구간': '서울대입구↔을지입구', '기관': '서울교통공사', '역개수': 16, '연번': 7, '연장(km)': '19.8', '호선': 2}, {'개통일자': '1992-05-22', '구간': '신도림↔양천구청', '기관': '서울교통공사', '역개수': 2, '연번': 8, '연장(km)': '2.7', '호선': 2}, {'개통일자': '1996-02-29', '구간': '양천구청↔신정네거리', '기관': '서울교통공사', '역개수': 1, '연번': 9, '연장(km)': '1.9', '호선': 2}, {'개통일자': '1996-03-20', '구간': '신정네거리↔까치산', '기관': '서울교통공사', '역개수': None, '연번': 10, '연장(km)': '1.4', '호선': 2}, {'개통일자': '2005-10-20', '구간': '용두', '기관': '서울교통공사', '역개수': 1, '연번': 11, '연장(km)': None, '호선': 2}, {'개통일자': '1985-07-12', '구간': '구파발↔독립문', '기관': '서울교통공사', '역개수': 7, '연번': 12, '연장(km)': '8.0', '호선': 3}, {'개통일자': '1985-10-18', '구간': '독립문↔양재', '기관': '서울교통공사', '역개수': 16, '연번': 13, '연장(km)': '18.2', '호선': 3}, {'개통일자': '1990-07-13', '구간': '지축↔구파발', '기관': '서울교통공사', '역개수': 1, '연번': 14, '연장(km)': '1.5', '호선': 3}, {'개통일자': '1993-10-30', '구간': '양재↔수서', '기관': '서울교통공사', '역개수': 7, '연번': 15, '연장(km)': '7.5', '호선': 3}, {'개통일자': '2010-02-18', '구간': '수서↔오금', '기관': '서울교통공사', '역개수': 3, '연번': 16, '연장(km)': '3.0', '호선': 3}, {'개통일자': '1985-04-20', '구간': '상계↔한성대입구', '기관': '서울교통공사', '역개수': 10, '연번': 17, '연장(km)': '11.8', '호선': 4}, {'개통일자': '1985-10-18', '구간': '한성대입구↔사당', '기관': '서울교통공사', '역개수': 14, '연번': 18, '연장(km)': '16.5', '호선': 4}, {'개통일자': '1993-04-21', '구간': '당고개↔상계', '기관': '서울교통공사', '역개수': 1, '연번': 19, '연장(km)': '1.2', '호선': 4}, {'개통일자': '1994-04-01', '구간': '사당↔남태령(시계)', '기관': '서울교통공사', '역개수': 1, '연번': 20, '연장(km)': '2.2', '호선': 4}, {'개통일자': '2022-03-19', '구간': '당고개↔진접', '기관': '서울교통공사', '역개수': 3, '연번': 21, '연장(km)': '14.2', '호선': 4}, {'개통일자': '1995-11-15', '구간': '왕십리↔상일동', '기관': '서울교통공사', '역개수': 14, '연번': 22, '연장(km)': '14.4', '호선': 5}, {'개통일자': '1996-03-20', '구간': '방화↔까치산', '기관': '서울교통공사', '역개수': 9, '연번': 23, '연장(km)': '8.9', '호선': 5}, {'개통일자': '1996-03-30', '구간': '강동↔마천', '기관': '서울교통공사', '역개수': 7, '연번': 24, '연장(km)': '7.1', '호선': 5}, {'개통일자': '1996-08-12', '구간': '까치산↔여의도', '기관': '서울교통공사', '역개수': 8, '연번': 25, '연장(km)': '7.9', '호선': 5}, {'개통일자': '1996-12-30', '구간': '여의도↔왕십리', '기관': '서울교통공사', '역개수': 13, '연번': 26, '연장(km)': '14.0', '호선': 5}, {'개통일자': '2020-08-08', '구간': '미사↔하남풍산', '기관': '서울교통공사', '역개수': 2, '연번': 27, '연장(km)': '4.6', '호선': 5}, {'개통일자': '2021-03-27', '구간': '강일↔하남검단산', '기관': '서울교통공사', '역개수': 3, '연번': 28, '연장(km)': '2.9', '호선': 5}, {'개통일자': '2000-08-07', '구간': '봉화산↔상월곡', '기관': '서울교통공사', '역개수': 6, '연번': 29, '연장(km)': '4.2', '호선': 6}, {'개통일자': '2000-12-15', '구간': '응암↔상월곡', '기관': '서울교통공사', '역개수': 28, '연번': 30, '연장(km)': '30.9', '호선': 6}, {'개통일자': '2001-03-09', '구간': '이태원↔약수', '기관': '서울교통공사', '역개수': 4, '연번': 31, '연장(km)': None, '호선': 6}, {'개통일자': '2019-12-21', '구간': '봉화산↔신내', '기관': '서울교통공사', '역개수': 1, '연번': 32, '연장(km)': '1.3', '호선': 6}, {'개통일자': '1996-10-11', '구간': '장암↔건대입구', '기관': '서울교통공사', '역개수': 19, '연번': 33, '연장(km)': '19.0', '호선': 7}, {'개통일자': '2000-02-29', '구간': '온수↔신풍', '기관': '서울교통공사', '역개수': 8, '연번': 34, '연장(km)': '9.2', '호선': 7}, {'개통일자': '2012-10-27', '구간': '온수↔부평구청', '기관': '서울교통공사', '역개수': 9, '연번': 35, '연장(km)': '10.2', '호선': 7}, {'개통일자': '2000-08-01', '구간': '건대입구↔신풍', '기관': '서울교통공사', '역개수': 15, '연번': 36, '연장(km)': '18.7', '호선': 7}, {'개통일자': '1996-11-23', '구간': '잠실↔모란', '기관': '서울교통공사', '역개수': 13, '연번': 37, '연장(km)': '13.1', '호선': 8}, {'개통일자': '1999-07-02', '구간': '암사↔잠실', '기관': '서울교통공사', '역개수': 4, '연번': 38, '연장(km)': '4.6', '호선': 8}, {'개통일자': '2021-12-18', '구간': '남위례', '기관': ' ...

# %%
opening_dict.keys()
# Out:
# dict_keys(['currentCount', 'data', 'matchCount', 'page', 'perPage', 'totalCount'])

# %%
print(opening_dict['data'][1]) # 1호선 개통일자
# Out:
# {'개통일자': '2005-12-21', '구간': '동묘앞', '기관': '서울교통공사', '역개수': 1, '연번': 2, '연장(km)': None, '호선': 1}
